# %% [markdown]
# <a href="https://colab.research.google.com/github/flowonthegoliv/ENVS666_2024/blob/main/read_plume.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt

# %%
url = "https://jonnyhigham.com/ENVS666/plume_api.php"
response = requests.get(url)
data = response.json()
sensors = data['sensorInfo']
df = pd.DataFrame(sensors)

df
# Out:
#    sensor_name           start_date             end_date
# 0    station_1  2021-09-21 19:41:22  2023-01-31 21:11:07
# 1   station_10  2021-09-28 08:58:22  2024-02-06 11:31:59
# 2   station_11  2021-09-28 08:58:30  2023-09-20 04:56:03
# 3   station_12  2021-10-11 08:25:34  2022-03-02 22:33:06
# 4   station_13  2021-09-27 09:55:28  2024-02-06 11:33:59
# 5    station_2  2021-10-05 08:33:51  2024-02-06 11:36:35
# 6    station_3  2021-10-05 08:56:35  2024-02-06 11:28:41
# 7    station_4  2021-10-05 08:47:11  2024-02-13 11:25:39
# 8    station_5  2021-09-28 13:11:58  2024-02-13 12:15:09
# 9    station_6  2021-09-28 08:59:27  2024-02-06 11:28:41
# 10   station_7  2021-09-28 08:43:36  2024-02-13 11:17:15
# 11   station_8                 None                 None
# 12   station_9  2021-09-28 09:08:11  2022-02-01 16:47:41

# %%
startDate = '2023-02-01'
endDate = '2024-02-27'
sensor = 4

url = "https://jonnyhigham.com/ENVS666/plume_api.php?sensor="+str(sensor)+"&startDate="+startDate+"&endDate="+endDate
response = requests.get(url)
data = response.json()
data = data['data']
df = pd.DataFrame(data)


df
# Out:
#                 Timestamp  Longitude  Latitude   NO2    VOC  PM1.0  PM2.5  \
# 0     2023-02-14 13:32:49   -2.96303  53.40481  0.45  134.5  11.64  12.64
# 1     2023-02-14 13:33:42   -2.96301  53.40482  1.42  115.5  10.88  11.88
# 2     2023-02-14 13:34:34   -2.96301  53.40480  2.46  108.0  13.81  14.81
# 3     2023-02-14 13:35:26   -2.96302  53.40480  2.96  106.0  17.65  18.65
# 4     2023-02-14 13:36:17   -2.96057  53.40242  3.02  104.5  17.46  18.46
# ...                   ...        ...       ...   ...    ...    ...    ...
# 1454  2024-02-13 11:23:57   -2.96307  53.40495  7.68  415.0   1.00   2.00
# 1455  2024-02-13 11:24:29   -2.96307  53.40495  7.68  415.0   1.00   2.00
# 1456  2024-02-13 11:24:55   -2.96326  53.40497  8.59  412.0   1.00   2.00
# 1457  2024-02-13 11:25:33   -2.96320  53.40497  8.59  412.0   1.00   2.00
# 1458  2024-02-13 11:25:39   -2.96335  53.40498  8.59  412.0   1.00   2.00
#
#       PM10.0
# 0      13.64
# 1      12.88
# 2      15.81
# 3      19.65
# 4      19.46
# ...      ...
# 1454    3.00
# 1455    3.00
# 1456    3.00
# 1457    3.00
# 1458    3.00
#
# [1459 rows x 8 columns]

# %%
plt.scatter(df['Longitude'], df['Latitude'], c=df['PM2.5'], cmap='viridis', alpha=1)  # Adjust 's' for marker size
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of PM2.5 Data')
plt.grid(True)
plt.colorbar(label='PM2.5')
plt.show()
